# %%
import pandas as pd
train = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')
df= pd.concat([train, test], ignore_index=True)

# %% [markdown]
# # Step 1: Understanding the data

# %%
df.head(10)
# Out:
#    Unnamed: 0      id  Gender      Customer Type  Age   Type of Travel  \
# 0           0   70172    Male     Loyal Customer   13  Personal Travel
# 1           1    5047    Male  disloyal Customer   25  Business travel
# 2           2  110028  Female     Loyal Customer   26  Business travel
# 3           3   24026  Female     Loyal Customer   25  Business travel
# 4           4  119299    Male     Loyal Customer   61  Business travel
# 5           5  111157  Female     Loyal Customer   26  Personal Travel
# 6           6   82113    Male     Loyal Customer   47  Personal Travel
# 7           7   96462  Female     Loyal Customer   52  Business travel
# 8           8   79485  Female     Loyal Customer   41  Business travel
# 9           9   65725    Male  disloyal Customer   20  Business travel
#
#       Class  Flight Distance  Inflight wifi service  \
# 0  Eco Plus              460                      3
# 1  Business              235                      3
# ...

# %%
df=df.iloc[:, 2:]
df.describe()
# Out:
#                  Age  Flight Distance  Inflight wifi service  \
# count  129880.000000    129880.000000          129880.000000
# mean       39.427957      1190.316392               2.728696
# std        15.119360       997.452477               1.329340
# min         7.000000        31.000000               0.000000
# 25%        27.000000       414.000000               2.000000
# 50%        40.000000       844.000000               3.000000
# 75%        51.000000      1744.000000               4.000000
# max        85.000000      4983.000000               5.000000
#
#        Departure/Arrival time convenient  Ease of Online booking  \
# count                      129880.000000           129880.000000
# mean                            3.057599                2.756876
# std                             1.526741                1.401740
# min                             0.000000                0.000000
# 25%                             2.000000                2.000000
# ...

# %%
# Get basic statistics for categorical features
print(df.describe(include=['object']))
# Out:
#         Gender   Customer Type   Type of Travel     Class  \
# count   129880          129880           129880    129880
# unique       2               2                2         3
# top     Female  Loyal Customer  Business travel  Business
# freq     65899          106100            89693     62160
#
#                    satisfaction
# count                    129880
# unique                        2
# top     neutral or dissatisfied
# freq                      73452

# %%
df.shape
# Out:
# (129880, 23)

# %%
df.columns
# Out:
# Index(['Gender', 'Customer Type', 'Age', 'Type of Travel', 'Class',
#        'Flight Distance', 'Inflight wifi service',
#        'Departure/Arrival time convenient', 'Ease of Online booking',
#        'Gate location', 'Food and drink', 'Online boarding', 'Seat comfort',
#        'Inflight entertainment', 'On-board service', 'Leg room service',
#        'Baggage handling', 'Checkin service', 'Inflight service',
#        'Cleanliness', 'Departure Delay in Minutes', 'Arrival Delay in Minutes',
#        'satisfaction'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Gender                                object
# Customer Type                         object
# Age                                    int64
# Type of Travel                        object
# Class                                 object
# Flight Distance                        int64
# Inflight wifi service                  int64
# Departure/Arrival time convenient      int64
# Ease of Online booking                 int64
# Gate location                          int64
# Food and drink                         int64
# Online boarding                        int64
# Seat comfort                           int64
# Inflight entertainment                 int64
# On-board service                       int64
# Leg room service                       int64
# Baggage handling                       int64
# Checkin service                        int64
# Inflight service                       int64
# Cleanliness                            int64
# Departure Delay in Minutes             int64
# ...

# %% [markdown]
# # Step 2: Data Cleaning

# %%
# Check for missing values
print(df.isnull().sum())
# Out:
# Gender                                 0
# Customer Type                          0
# Age                                    0
# Type of Travel                         0
# Class                                  0
# Flight Distance                        0
# Inflight wifi service                  0
# Departure/Arrival time convenient      0
# Ease of Online booking                 0
# Gate location                          0
# Food and drink                         0
# Online boarding                        0
# Seat comfort                           0
# Inflight entertainment                 0
# On-board service                       0
# Leg room service                       0
# Baggage handling                       0
# Checkin service                        0
# Inflight service                       0
# Cleanliness                            0
# Departure Delay in Minutes             0
# Arrival Delay in Minutes             393
# satisfaction                           0
# ...

# %%
from sklearn.impute import KNNImputer
import numpy as np
# Initialize the KNN imputer
imputer = KNNImputer(n_neighbors=5)

# Apply KNN imputation to 'Arrival Delay in Minutes'
imputed_values = imputer.fit_transform(df[['Arrival Delay in Minutes']])
# Update only the missing values in 'Arrival Delay in Minutes'
df['Arrival Delay in Minutes'] = np.where(df['Arrival Delay in Minutes'].isnull(),
                                          imputed_values[:, 0],
                                          df['Arrival Delay in Minutes'])
# Check if missing values are filled
print(df['Arrival Delay in Minutes'].isnull().sum())
# Out:
# 0

# %%
# Check for outliers
import pandas as pd

# Function to detect outliers using the IQR method
def detect_outliers_iqr(df, column):
    Q1 = df[column].quantile(0.25)  # 25th percentile
    Q3 = df[column].quantile(0.75)  # 75th percentile
    IQR = Q3 - Q1  # Interquartile Range
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    
    # Detect outliers
    outliers = df[(df[column] < lower_bound) | (df[column] > upper_bound)]
    return outliers

# Check for outliers in relevant numerical columns
numerical_columns = df.select_dtypes(include=['int64', 'float64']).columns
for column in numerical_columns:
    outliers = detect_outliers_iqr(df, column)
    if not outliers.empty:
        print(f"Outliers detected in {column}: {outliers.shape[0]} rows")
    else:
        print(f"No outliers detected in {column}")
# Out:
# No outliers detected in Age
# Outliers detected in Flight Distance: 2855 rows
# No outliers detected in Inflight wifi service
# No outliers detected in Departure/Arrival time convenient
# No outliers detected in Ease of Online booking
# No outliers detected in Gate location
# No outliers detected in Food and drink
# No outliers detected in Online boarding
# No outliers detected in Seat comfort
# No outliers detected in Inflight entertainment
# No outliers detected in On-board service
# No outliers detected in Leg room service
# No outliers detected in Baggage handling
# Outliers detected in Checkin service: 16109 rows
# No outliers detected in Inflight service
# No outliers detected in Cleanliness
# Outliers detected in Departure Delay in Minutes: 18098 rows
# Outliers detected in Arrival Delay in Minutes: 17492 rows

# %%
# Remove the outliers
# Function to remove outliers using the IQR method
def remove_outliers_iqr(df, column):
    Q1 = df[column].quantile(0.25)  # 25th percentile
    Q3 = df[column].quantile(0.75)  # 75th percentile
    IQR = Q3 - Q1  # Interquartile Range
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    
    # Remove outliers
    df_filtered = df[(df[column] >= lower_bound) & (df[column] <= upper_bound)]
    
    return df_filtered

columns_with_outliers = ['Flight Distance', 'Checkin service', 'Departure Delay in Minutes', 'Arrival Delay in Minutes']

for column in columns_with_outliers:
    df = remove_outliers_iqr(df, column)
print(f"Shape after removing outliers: {df.shape}")
# Out:
# Shape after removing outliers: (82637, 23)

# %% [markdown]
# # Step 3: EDA

# %%
import matplotlib.pyplot as plt
# Check the distribution of the target class 'satisfaction'
target_distribution = df['satisfaction'].value_counts()
print("Distribution of Target Class:")
print(target_distribution)
# Out:
# Distribution of Target Class:
# satisfaction
# neutral or dissatisfied    43067
# satisfied                  39570
# Name: count, dtype: int64

# %%
# Plot the pie chart
plt.figure(figsize=(8, 6))
colors = ['#1f77b4', '#ffcc00']  # Blue and Gold colors
target_distribution.plot.pie(autopct='%1.1f%%', startangle=140, colors=colors)
plt.title('Distribution of Target Class (Satisfaction)')
plt.ylabel('')  #
# Out:
# Text(0, 0.5, '')

# %%
gender_counts = df['Gender'].value_counts()
# Plot a pie chart
plt.figure(figsize=(8, 6))
colors = ['#1f77b4', '#ffcc00']  # Blue and Gold colors
gender_counts.plot.pie(autopct='%1.1f%%', startangle=140, colors=colors)
plt.title('Gender Distribution')
plt.ylabel('')  # Remove the y-label for clarity
plt.show()

# %%
import plotly.express as px
import plotly.graph_objects as go

satisfaction_dist = df.groupby(['Gender', 'satisfaction']).size().reset_index(name='Count')
satisfaction_dist['Proportion'] = satisfaction_dist.groupby('Gender')['Count'].transform(lambda x: x / x.sum())

fig = go.Figure()

for satisfaction_level in satisfaction_dist['satisfaction'].unique():
    subset = satisfaction_dist[satisfaction_dist['satisfaction'] == satisfaction_level]
    fig.add_trace(go.Bar(
        x=subset['Gender'],
        y=subset['Proportion'],
        name=str(satisfaction_level),
        text=[f'{p*100:.1f}%' for p in subset['Proportion']],
        textposition='inside'
    ))

fig.update_layout(
    barmode='stack',
    title='Satisfaction Level Based on Gender',
    xaxis_title='Gender',
    yaxis_title='Proportion',
    xaxis_tickvals=list(satisfaction_dist['Gender'].unique())
)

fig.show()

# %%
customer_type_dist = df['Customer Type'].value_counts()
plt.figure(figsize=(5, 5))
plt.pie(customer_type_dist, labels=customer_type_dist.index, autopct='%1.1f%%', colors=['#1f77b4', '#ffcc00'])
plt.title('Customer Type Distribution')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Group by 'Customer Type' and 'satisfaction', calculate counts
satisfaction_dist = df.groupby(['Customer Type', 'satisfaction']).size().unstack().fillna(0)
satisfaction_dist = satisfaction_dist.divide(satisfaction_dist.sum(axis=1), axis=0) * 100

# Convert to long format for Seaborn
satisfaction_long = satisfaction_dist.reset_index().melt(id_vars='Customer Type', var_name='satisfaction', value_name='Percentage')

plt.figure(figsize=(5,5))
sns.barplot(x='Customer Type', y='Percentage', hue='satisfaction', data=satisfaction_long, palette=['#1f77b4', '#ffcc00'])

# Add percentages on top of the bars
for p in plt.gca().patches:
    plt.text(p.get_x() + p.get_width() / 2, p.get_height() + 1,
             f'{p.get_height():.1f}%', ha='center',  fontsize=10)

plt.title('Satisfaction Distribution Based on Customer Type')
plt.xlabel('Customer Type')
plt.ylabel('Percentage')
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
#Overall distribution of the categorical variables
# List of categorical features
categorical_features = ['Gender', 'Customer Type', 'Type of Travel', 'Class', 'satisfaction']
# Plot frequency distributions for each categorical feature
plt.figure(figsize=(15, 10))
for i, feature in enumerate(categorical_features, 1):
    plt.subplot(2, 3, i)  # Adjust subplot grid as needed
    sns.countplot(x=feature, data=df, palette='Set2')
    plt.title(f'Distribution of {feature}')
    plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\elroy\AppData\Local\Temp\ipykernel_3496\2385580154.py:9: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#
# C:\Users\elroy\AppData\Local\Temp\ipykernel_3496\2385580154.py:9: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#
# C:\Users\elroy\AppData\Local\Temp\ipykernel_3496\2385580154.py:9: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#
# C:\Users\elroy\AppData\Local\Temp\ipykernel_3496\2385580154.py:9: FutureWarning:
#
#
#
# ...

# %%
# Gaussian Distribution of numerical features
numerical_features = ['Age', 'Flight Distance', 'Departure Delay in Minutes', 'Arrival Delay in Minutes']
# Plot distribution for each numerical feature
plt.figure(figsize=(10, 10))
for i, feature in enumerate(numerical_features, 1):
    plt.subplot(2, 2, i)  # Adjust subplot grid as needed
    sns.histplot(df[feature], kde=True, color='darkblue', line_kws={'color': 'red'})
    plt.title(f'Distribution of {feature}')
    plt.xlabel(feature)
    plt.ylabel('Density')
plt.tight_layout()
plt.show()

# %%
sns.pairplot(df[numerical_features], diag_kind='kde', palette='coolwarm')
plt.suptitle('Pairplot of Numerical Features', y=1.02)
plt.show()
# Out:
# C:\Users\elroy\anaconda3\envs\myenv\Lib\site-packages\seaborn\axisgrid.py:1513: UserWarning:
#
# Ignoring `palette` because no `hue` variable has been assigned.
#
# C:\Users\elroy\anaconda3\envs\myenv\Lib\site-packages\seaborn\axisgrid.py:1513: UserWarning:
#
# Ignoring `palette` because no `hue` variable has been assigned.
#
# C:\Users\elroy\anaconda3\envs\myenv\Lib\site-packages\seaborn\axisgrid.py:1513: UserWarning:
#
# Ignoring `palette` because no `hue` variable has been assigned.
#
# C:\Users\elroy\anaconda3\envs\myenv\Lib\site-packages\seaborn\axisgrid.py:1513: UserWarning:
#
# Ignoring `palette` because no `hue` variable has been assigned.
#
# C:\Users\elroy\anaconda3\envs\myenv\Lib\site-packages\seaborn\axisgrid.py:1615: UserWarning:
#
# Ignoring `palette` because no `hue` variable has been assigned.
#
# C:\Users\elroy\anaconda3\envs\myenv\Lib\site-packages\seaborn\axisgrid.py:1615: UserWarning:
#
# Ignoring `palette` because no `hue` variable has been assigned.
#
# ...

# %%
# Correlation 
# Compute the correlation matrix
corr = df[['Age', 'Flight Distance', 'Departure Delay in Minutes', 'Arrival Delay in Minutes']].corr()
plt.figure(figsize=(5, 5))
sns.heatmap(corr, annot=True, cmap='Blues', fmt='.2f', linewidths=.5)
plt.title('Correlation Heatmap of Numerical Features')
plt.show()

# %%
from sklearn.preprocessing import LabelEncoder
df_encoded = df.copy()
le = LabelEncoder()
categorical_features = ['Gender', 'Customer Type', 'Type of Travel', 'Class', 'satisfaction']
for feature in categorical_features:
    df_encoded[feature] = le.fit_transform(df_encoded[feature])
corr_matrix = df_encoded.corr()
plt.figure(figsize=(25, 20))
sns.heatmap(corr_matrix, annot=True, cmap='Blues', fmt='.2f', linewidths=.5)
plt.title('Correlation Heatmap with Categorical Variables')
plt.show()

# %%
abs_corr_matrix = corr_matrix.abs()
# Find pairs with high correlation
threshold = 0.5
high_corr_pairs = (abs_corr_matrix.where(abs_corr_matrix > threshold)
                   .stack()
                   .reset_index()
                   .rename(columns={0: 'Correlation'}))

# Remove self-correlations
high_corr_pairs = high_corr_pairs[high_corr_pairs['level_0'] != high_corr_pairs['level_1']]
# Remove duplicate pairs
high_corr_pairs = high_corr_pairs.drop_duplicates(subset=['Correlation'])
# Sort by correlation value
high_corr_pairs = high_corr_pairs.sort_values(by='Correlation', ascending=False)
print(high_corr_pairs)
# Out:
#                    level_0                 level_1  Correlation
# 9    Inflight wifi service  Ease of Online booking     0.752753
# 27  Inflight entertainment             Cleanliness     0.709324
# 23            Seat comfort             Cleanliness     0.675878
# 17          Food and drink             Cleanliness     0.666737
# 34        Baggage handling        Inflight service     0.639752
# 16          Food and drink  Inflight entertainment     0.635993
# 22            Seat comfort  Inflight entertainment     0.627954
# 15          Food and drink            Seat comfort     0.580228
# 30        On-board service        Inflight service     0.573841
# 29        On-board service        Baggage handling     0.539990
# 4           Type of Travel                   Class     0.525683
# 19         Online boarding            satisfaction     0.505674

# %% [markdown]
# # Insights from High Correlation Pairs
# Inflight Wifi Service and Ease of Online Booking (0.75):
# Insight: These two features are highly correlated. This suggests that customers who rate inflight wifi service highly tend to also find online booking more convenient, and vice versa. Improving one might positively impact the other.
#
# Inflight Entertainment and Cleanliness (0.71):
# Insight: There is a strong correlation between inflight entertainment and cleanliness. Passengers who rate inflight entertainment highly are also likely to rate cleanliness highly. This implies that the overall passenger experience could be improved by addressing both entertainment and cleanliness together.
#
# Seat Comfort and Cleanliness (0.68):
# Insight: Passengers who find the seat comfort satisfactory are also more likely to find cleanliness satisfactory. This indicates that seat comfort and cleanliness are closely linked in the passengers' perception of their overall experience.
#
# Food and Drink and Cleanliness (0.67):
# Insight: A high rating for food and drink is associated with a high rating for cleanliness. Ensuring clean dining areas might enhance passengers' satisfaction with food and drink services.
#
# Baggage Handling and Inflight Service (0.64):
# Insight: Efficient baggage handling correlates with better inflight service. Improving baggage handling could potentially lead to better perceptions of inflight service.
#
# Food and Drink and Inflight Entertainment (0.64):
# Insight: Passengers who are satisfied with food and drink services tend to also be satisfied with inflight entertainment. These aspects of the service might influence each other.
#
# Seat Comfort and Inflight Entertainment (0.63):
# Insight: There is a notable correlation between seat comfort and inflight entertainment. Enhancing the comfort of seats might have a positive impact on passengers' experience with inflight entertainment.
#
# Food and Drink and Seat Comfort (0.58):
# Insight: Passengers who find food and drink satisfactory also tend to find seat comfort satisfactory. Ensuring high standards in one area may positively influence the other.
#
# On-Board Service and Inflight Service (0.57):
# Insight: A strong correlation exists between on-board service and inflight service. Improvements in one area might positively affect perceptions of the other.
#
# On-Board Service and Baggage Handling (0.54):
# Insight: Better on-board service is related to better baggage handling. Both aspects of the service experience are connected, and enhancing one could potentially improve the other.
#
# Type of Travel and Class (0.53):
# Insight: There is a moderate correlation between the type of travel and the class. Passengers’ travel type may influence their choice of class, or vice versa.
#
# Online Boarding and Satisfaction (0.51):
# Insight: A higher rating for online boarding is associated with higher satisfaction levels. Improving the online boarding process could enhance overall passenger satisfaction.
#
# Summary:
# Service Quality: Features related to service quality (e.g., inflight entertainment, cleanliness, food and drink) are often interrelated. Improving one area may positively impact others.
# Passenger Experience: Correlations suggest that enhancing comfort, entertainment, and service can lead to a better overall passenger experience.
# Operational Focus: Addressing issues in high-correlation areas can have a significant impact on passenger satisfaction.
# By focusing on these key areas, you can potentially improve overall passenger satisfaction and streamline service operations.

# %%
df_encoded.dtypes
# Out:
# Gender                                 int32
# Customer Type                          int32
# Age                                    int64
# Type of Travel                         int32
# Class                                  int32
# Flight Distance                        int64
# Inflight wifi service                  int64
# Departure/Arrival time convenient      int64
# Ease of Online booking                 int64
# Gate location                          int64
# Food and drink                         int64
# Online boarding                        int64
# Seat comfort                           int64
# Inflight entertainment                 int64
# On-board service                       int64
# Leg room service                       int64
# Baggage handling                       int64
# Checkin service                        int64
# Inflight service                       int64
# Cleanliness                            int64
# Departure Delay in Minutes             int64
# ...

# %%
# Use PCA 
from sklearn.decomposition import PCA
pca = PCA(n_components=2)
pca_result = pca.fit_transform(df_encoded.select_dtypes(include=['float64', 'int64','int32']))
print(f"Explained Variance Ratios: {pca.explained_variance_ratio_}")
# Out:
# Explained Variance Ratios: [9.99674270e-01 2.60260438e-04]

# %%
df.columns
# Out:
# Index(['Gender', 'Customer Type', 'Age', 'Type of Travel', 'Class',
#        'Flight Distance', 'Inflight wifi service',
#        'Departure/Arrival time convenient', 'Ease of Online booking',
#        'Gate location', 'Food and drink', 'Online boarding', 'Seat comfort',
#        'Inflight entertainment', 'On-board service', 'Leg room service',
#        'Baggage handling', 'Checkin service', 'Inflight service',
#        'Cleanliness', 'Departure Delay in Minutes', 'Arrival Delay in Minutes',
#        'satisfaction'],
#       dtype='object')

# %%
# Define age groups (bins)
bins = [0, 18, 25, 35, 45, 55, 65, 75, 85, 100]
labels = ['0-18', '19-25', '26-35', '36-45', '46-55', '56-65', '66-75', '76-85', '86-100']
# Create a new column in the dataframe for age groups
df['AgeGroup'] = pd.cut(df['Age'], bins=bins, labels=labels, right=False)
# Calculate the satisfaction rate by age group
satisfaction_by_age = df.groupby('AgeGroup')['satisfaction'].mean().reset_index()

# %%
df
# Out:
#         Gender      Customer Type  Age   Type of Travel     Class  \
# 2       Female     Loyal Customer   26  Business travel  Business
# 4         Male     Loyal Customer   61  Business travel  Business
# 5       Female     Loyal Customer   26  Personal Travel       Eco
# 7       Female     Loyal Customer   52  Business travel  Business
# 8       Female     Loyal Customer   41  Business travel  Business
# ...        ...                ...  ...              ...       ...
# 129874  Female  disloyal Customer   36  Business travel       Eco
# 129875    Male  disloyal Customer   34  Business travel  Business
# 129876    Male     Loyal Customer   23  Business travel  Business
# 129877  Female     Loyal Customer   17  Personal Travel       Eco
# 129878    Male     Loyal Customer   14  Business travel  Business
#
#         Flight Distance  Inflight wifi service  \
# 2                  1142                      2
# 4                   214                      3
# ...

# %%
# Group by 'AgeGroup' and count satisfaction values
age_satisfaction_counts = df.groupby('AgeGroup')['satisfaction'].value_counts().unstack().reset_index()
melted_df = age_satisfaction_counts.melt(id_vars='AgeGroup', var_name='Satisfaction', value_name='Count')

# Plot with Plotly
fig = px.bar(melted_df, x='AgeGroup', y='Count', color='Satisfaction',
             color_discrete_map={'Neutral': '#FFA07A', 'Satisfied': '#FF6347', 'Very Dissatisfied': '#FF4500'},
             labels={'Count': 'Count', 'AgeGroup': 'Age Group', 'Satisfaction': 'Satisfaction'},
             title='Distribution of Satisfaction by Age Group',
             height=600)
fig.update_layout(
    xaxis_title='Age Group',
    yaxis_title='Count',
    legend_title='Satisfaction',
    xaxis_tickangle=-45,
    xaxis_title_font_size=14,
    yaxis_title_font_size=14,
    title_font_size=16,
    title_font_family='Arial'
)

fig.show()
# Out:
# C:\Users\elroy\AppData\Local\Temp\ipykernel_3496\3769253121.py:2: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.

# %%
class_satisfaction_counts = df.groupby('Class')['satisfaction'].value_counts().unstack().reset_index()
melted_df = class_satisfaction_counts.melt(id_vars='Class', var_name='Satisfaction', value_name='Count')

fig = px.bar(melted_df, x='Class', y='Count', color='Satisfaction',
             color_discrete_map={'Neutral': '#FFA07A', 'Satisfied': '#FF6347', 'Very Dissatisfied': '#FF4500'},
             labels={'Count': 'Count', 'Class': 'Class', 'Satisfaction': 'Satisfaction'},
             title='Distribution of Satisfaction by Class',
             height=600)
fig.update_layout(
    xaxis_title='Class',
    yaxis_title='Count',
    legend_title='Satisfaction',
    xaxis_title_font_size=14,
    yaxis_title_font_size=14,
    title_font_size=16,
    title_font_family='Arial'
)

# %%
travel_type_counts = df['Type of Travel'].value_counts()
fig = go.Figure(data=[go.Pie(
    labels=travel_type_counts.index,
    values=travel_type_counts.values,
    hole=0.3,  # Optional: Creates a donut chart
    textinfo='label+percent',  # Displays label and percentage
    marker=dict(colors=['#ff7f0e', '#1f77b4']),  # Customize colors as needed
)])

fig.update_layout(
    title='Distribution of Travel Types',
    title_font_size=16,
    title_font_family='Arial'
)

fig.show()

# %%
# Flight distance across Classes
plt.figure(figsize=(12, 8))
sns.boxplot(x='Class', y='Flight Distance', data=df, palette='Purples')
plt.title('Flight Distance Distribution by Class')
plt.show()
# Out:
# C:\Users\elroy\AppData\Local\Temp\ipykernel_3496\3095322813.py:3: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.

# %%
# Flight distance by age groups
# Calculate average flight distance by age group
mean_flight_distance = df.groupby('AgeGroup')['Flight Distance'].mean()
plt.figure(figsize=(5, 5))
mean_flight_distance.plot(kind='bar', color='#6D6E7F', edgecolor='black')
plt.title('Average Flight Distance by Age Group', fontsize=16, fontweight='bold')
plt.xlabel('Age Group', fontsize=14)
plt.ylabel('Average Flight Distance', fontsize=14)
plt.xticks(rotation=45, fontsize=12)
plt.yticks(fontsize=12)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\elroy\AppData\Local\Temp\ipykernel_3496\948686873.py:3: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.

# %% [markdown]
# # Hence we can say that highest satisfaction rate also depends on the distance flown , in this case 46-55 age group has flown the highest distance

# %%
# Cross -checking the above
mean_flight_distance_by_satisfaction = df.groupby('satisfaction')['Flight Distance'].mean()
# Plot
plt.figure(figsize=(12, 8))
plt.bar(mean_flight_distance_by_satisfaction.index, mean_flight_distance_by_satisfaction, color='darkblue', edgecolor='black')  # Blue Lilac
plt.title('Average Flight Distance by Satisfaction Category', fontsize=16)
plt.xlabel('Satisfaction Category', fontsize=14)
plt.ylabel('Average Flight Distance', fontsize=14)
plt.xticks(rotation=45, fontsize=12)
plt.yticks(fontsize=12)
plt.tight_layout()
plt.show()

# %%
df.columns
# Out:
# Index(['Gender', 'Customer Type', 'Age', 'Type of Travel', 'Class',
#        'Flight Distance', 'Inflight wifi service',
#        'Departure/Arrival time convenient', 'Ease of Online booking',
#        'Gate location', 'Food and drink', 'Online boarding', 'Seat comfort',
#        'Inflight entertainment', 'On-board service', 'Leg room service',
#        'Baggage handling', 'Checkin service', 'Inflight service',
#        'Cleanliness', 'Departure Delay in Minutes', 'Arrival Delay in Minutes',
#        'satisfaction', 'AgeGroup'],
#       dtype='object')

# %%
# Average ratings of the services
rating_columns = [
    'Inflight wifi service', 'Departure/Arrival time convenient', 'Ease of Online booking',
    'Gate location', 'Food and drink', 'Online boarding', 'Seat comfort',
    'Inflight entertainment', 'On-board service', 'Leg room service',
    'Baggage handling', 'Checkin service', 'Inflight service',
    'Cleanliness'
]
average_ratings = df[rating_columns].mean()
# Plot
plt.figure(figsize=(14, 8))
average_ratings.plot(kind='bar', color='teal', edgecolor='black')
plt.title('Average Ratings for Service Categories', fontsize=16)
plt.xlabel('Service Category', fontsize=14)
plt.ylabel('Average Rating', fontsize=14)
plt.xticks(rotation=35, fontsize=12)
plt.yticks(fontsize=12)
plt.tight_layout()
plt.show()

# %%
average_ratings_by_class = df.groupby('Class')[rating_columns].mean()

# Transpose the DataFrame for plotting
average_ratings_by_class = average_ratings_by_class.T

# Plot
plt.figure(figsize=(30, 30))
average_ratings_by_class.plot(kind='barh', colormap='Set1', edgecolor='black')
plt.title('Average Ratings by Service Category and Class Type', fontsize=16)
plt.xlabel('Average Rating', fontsize=14)
plt.ylabel('Service Categories', fontsize=14)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.legend(title='Class Type', bbox_to_anchor=(1.05, 1), loc='upper left', fontsize=12)
plt.tight_layout()
plt.show()

# %%
# Feature Engineering 
df_encoded.shape
# Out:
# (82637, 23)

# %%
df_encoded
# Out:
#         Gender  Customer Type  Age  Type of Travel  Class  Flight Distance  \
# 2            0              0   26               0      0             1142
# 4            1              0   61               0      0              214
# 5            0              0   26               1      1             1180
# 7            0              0   52               0      0             2035
# 8            0              0   41               0      0              853
# ...        ...            ...  ...             ...    ...              ...
# 129874       0              1   36               0      1              432
# 129875       1              1   34               0      0              526
# 129876       1              0   23               0      0              646
# 129877       0              0   17               1      1              828
# 129878       1              0   14               0      0             1127
#
#         Inflight wifi service  Departure/Arrival time convenient  \
# ...

# %% [markdown]
# # Step 4: Feature Engineering

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
X = df_encoded.drop('satisfaction', axis=1)
y = df_encoded['satisfaction']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
model = RandomForestClassifier(n_estimators=100, random_state=42)
model.fit(X_train, y_train)
importances = model.feature_importances_
feature_importances = pd.DataFrame({'Feature': X.columns, 'Importance': importances})
feature_importances = feature_importances.sort_values(by='Importance', ascending=False)

# %%
# Plot feature importances
plt.figure(figsize=(20, 18))
plt.barh(feature_importances['Feature'], feature_importances['Importance'], color='darkblue', edgecolor='black')
plt.title('Feature Importance from Random Forest', fontsize=16)
plt.xlabel('Importance', fontsize=14)
plt.ylabel('Feature', fontsize=14)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.tight_layout()
plt.show()

# %%
feature_importances
# Out:
#                               Feature  Importance
# 11                    Online boarding    0.185505
# 6               Inflight wifi service    0.141565
# 4                               Class    0.109246
# 3                      Type of Travel    0.096410
# 13             Inflight entertainment    0.057631
# 8              Ease of Online booking    0.045038
# 12                       Seat comfort    0.039822
# 5                     Flight Distance    0.038995
# 15                   Leg room service    0.038773
# 2                                 Age    0.036261
# 1                       Customer Type    0.033425
# 19                        Cleanliness    0.025646
# 14                   On-board service    0.024406
# 18                   Inflight service    0.020741
# 17                    Checkin service    0.020309
# 16                   Baggage handling    0.020131
# 9                       Gate location    0.017378
# 7   Departure/Arrival time convenient    0.016490
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Feature importances data
feature_importances = pd.DataFrame({
    'Feature': [
        'Online boarding', 'Inflight wifi service', 'Class', 'Type of Travel', 'Inflight entertainment', 
        'Ease of Online booking', 'Seat comfort', 'Flight Distance', 'Leg room service', 'Age', 
        'Customer Type', 'Cleanliness', 'On-board service', 'Inflight service', 'Checkin service', 
        'Baggage handling', 'Gate location', 'Departure/Arrival time convenient', 'Food and drink', 
        'Departure Delay in Minutes', 'Arrival Delay in Minutes', 'Gender'
    ],
    'Importance': [
        0.185505, 0.141565, 0.109246, 0.096410, 0.057631, 
        0.045038, 0.039822, 0.038995, 0.038773, 0.036261, 
        0.033425, 0.025646, 0.024406, 0.020741, 0.020309, 
        0.020131, 0.017378, 0.016490, 0.011099, 0.008170, 
        0.007521, 0.005438
    ]
})

# Number of top features to select
num_top_features = 10

# Select top features based on importance
top_features = feature_importances.nlargest(num_top_features, 'Importance')

# Plot
plt.figure(figsize=(12, 8))
plt.barh(top_features['Feature'], top_features['Importance'], color='darkblue', edgecolor='black')
plt.title('Top 10 Feature Importances from Random Forest', fontsize=16)
plt.xlabel('Importance', fontsize=14)
plt.ylabel('Feature', fontsize=14)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.tight_layout()
plt.show()

# %%
top_features['Feature']
# Out:
# 0           Online boarding
# 1     Inflight wifi service
# 2                     Class
# 3            Type of Travel
# 4    Inflight entertainment
# 5    Ease of Online booking
# 6              Seat comfort
# 7           Flight Distance
# 8          Leg room service
# 9                       Age
# Name: Feature, dtype: object

# %%
selected_features = [
    'Online boarding',
    'Inflight wifi service',
    'Class',
    'Type of Travel',
    'Inflight entertainment',
    'Ease of Online booking',
    'Seat comfort',
    'Flight Distance',
    'Leg room service',
    'Age'
]

corr_matrix = df_encoded[selected_features].corr()
plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix, annot=True, cmap='Blues', linewidths=0.5)
plt.title('Correlation Matrix of Selected Features')
plt.show()

# %%
import xgboost as xgb
X = df_encoded.drop('satisfaction', axis=1)
y = df_encoded['satisfaction']
model = xgb.XGBClassifier()
model.fit(X, y)
importance = model.feature_importances_
features = X.columns
feature_importance_df = pd.DataFrame({'Feature': features, 'Importance': importance})
top_features = feature_importance_df.sort_values(by='Importance', ascending=False).head(10)
print(top_features)
# Out:
#                    Feature  Importance
# 11         Online boarding    0.454617
# 3           Type of Travel    0.146000
# 6    Inflight wifi service    0.111639
# 1            Customer Type    0.059168
# 4                    Class    0.038065
# 13  Inflight entertainment    0.027392
# 17         Checkin service    0.024971
# 19             Cleanliness    0.018711
# 12            Seat comfort    0.017728
# 14        On-board service    0.017513

# %%
top_features_sorted = top_features.sort_index()
print(top_features_sorted)
# Out:
#                    Feature  Importance
# 1            Customer Type    0.059168
# 3           Type of Travel    0.146000
# 4                    Class    0.038065
# 6    Inflight wifi service    0.111639
# 11         Online boarding    0.454617
# 12            Seat comfort    0.017728
# 13  Inflight entertainment    0.027392
# 14        On-board service    0.017513
# 17         Checkin service    0.024971
# 19             Cleanliness    0.018711

# %%
#pLot the scale
data = top_features_sorted.set_index('Feature').T
# Plotting the heatmap
plt.figure(figsize=(10, 4))
sns.heatmap(data, annot=True, cmap='Purples', cbar=False, fmt='.2f', linewidths=0.5)
plt.title('Feature Importances Heatmap')
plt.show()

# %%
features_of_interest = [
    'Customer Type', 'Type of Travel', 'Class', 'Inflight wifi service', 
    'Online boarding', 'Seat comfort', 'Inflight entertainment', 
    'On-board service', 'Checkin service', 'Cleanliness'
]
df_selected = df_encoded[features_of_interest]
plt.figure(figsize=(12, 6))
sns.heatmap(df_selected.corr(), annot=True, cmap='Purples', fmt='.2f', linewidths=0.5)
plt.title('Correlation Heatmap of Selected Features')
plt.show()

# %%
from sklearn.model_selection import cross_val_score
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import GradientBoostingClassifier, RandomForestClassifier
from sklearn.svm import LinearSVC
from sklearn.linear_model import LogisticRegression
from sklearn.neural_network import MLPClassifier
# Define the models
models = {
    'GaussianNB': GaussianNB(),
    'GradientBoostingClassifier': GradientBoostingClassifier(),
    'LinearSVC': LinearSVC(max_iter=10000),
    'LogisticRegression': LogisticRegression(max_iter=10000),
    'MLPClassifier': MLPClassifier(max_iter=10000),
    'RandomForestClassifier': RandomForestClassifier()
}
X = df_encoded[features_of_interest]
y = df_encoded['satisfaction']

# Perform k-fold cross-validation
results = {}
for name, model in models.items():
    scores = cross_val_score(model, X, y, cv=5, scoring='accuracy')  # 5-fold cross-validation
    results[name] = scores.mean()
for model_name, mean_score in results.items():
    print(f'{model_name}: Mean Accuracy = {mean_score:.4f}')
# Out:
# C:\Users\elroy\anaconda3\envs\myenv\Lib\site-packages\sklearn\svm\_classes.py:31: FutureWarning:
#
# The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#
# C:\Users\elroy\anaconda3\envs\myenv\Lib\site-packages\sklearn\svm\_classes.py:31: FutureWarning:
#
# The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#
# C:\Users\elroy\anaconda3\envs\myenv\Lib\site-packages\sklearn\svm\_classes.py:31: FutureWarning:
#
# The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#
# C:\Users\elroy\anaconda3\envs\myenv\Lib\site-packages\sklearn\svm\_classes.py:31: FutureWarning:
#
# The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#
# ...

# %%
# Store accuracy scores in a DataFrame
accuracy_df = pd.DataFrame(list(results.items()), columns=['Model', 'Mean Accuracy'])
accuracy_df
# Out:
#                         Model  Mean Accuracy
# 0                  GaussianNB       0.867057
# 1  GradientBoostingClassifier       0.937958
# 2                   LinearSVC       0.861200
# 3          LogisticRegression       0.865036
# 4               MLPClassifier       0.947844
# 5      RandomForestClassifier       0.946404

# %%
import pickle
# Save each model to a pickle file
for name, model in models.items():
    with open(f'{name}.pkl', 'wb') as file:
        pickle.dump(model, file)
    print(f'Saved {name} model to {name}.pkl')
# Out:
# Saved GaussianNB model to GaussianNB.pkl
# Saved GradientBoostingClassifier model to GradientBoostingClassifier.pkl
# Saved LinearSVC model to LinearSVC.pkl
# Saved LogisticRegression model to LogisticRegression.pkl
# Saved MLPClassifier model to MLPClassifier.pkl
# Saved RandomForestClassifier model to RandomForestClassifier.pkl

# %%
from IPython.display import FileLink
# Generate download links for each model
for name in models.keys():
    file_link = FileLink(f'{name}.pkl')
    print(f'Download link for {name}: {file_link}')
# Out:
# Download link for GaussianNB: C:\Users\elroy\Machine Projects For SEM 2\GaussianNB.pkl
# Download link for GradientBoostingClassifier: C:\Users\elroy\Machine Projects For SEM 2\GradientBoostingClassifier.pkl
# Download link for LinearSVC: C:\Users\elroy\Machine Projects For SEM 2\LinearSVC.pkl
# Download link for LogisticRegression: C:\Users\elroy\Machine Projects For SEM 2\LogisticRegression.pkl
# Download link for MLPClassifier: C:\Users\elroy\Machine Projects For SEM 2\MLPClassifier.pkl
# Download link for RandomForestClassifier: C:\Users\elroy\Machine Projects For SEM 2\RandomForestClassifier.pkl

# %%
average_ratings
# Out:
# Inflight wifi service                2.760495
# Departure/Arrival time convenient    3.097051
# Ease of Online booking               2.764900
# Gate location                        2.959534
# Food and drink                       3.246766
# Online boarding                      3.329066
# Seat comfort                         3.507424
# Inflight entertainment               3.412781
# On-board service                     3.486174
# Leg room service                     3.403258
# Baggage handling                     3.717451
# Checkin service                      3.647349
# Inflight service                     3.743553
# Cleanliness                          3.348379
# dtype: float64
